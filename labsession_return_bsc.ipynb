# %%
2+2
# Out:
# 4

# %%
prices_a = [8.70,8.91,8.71]

# %%
8.91/8.70-1
# Out:
# 0.024137931034482918

# %%
8.71/8.91-1
# Out:
# -0.022446689113355678

# %%
prices_a[1:
        ]
# Out:
# [8.91, 8.71]

# %%
prices_a[:-1 ]
# Out:
# [8.7, 8.91]

# %%
import numpy as np

# %%
prices_a = np.array([8.70,8.91,8.71])
prices_a
# Out:
# array([8.7 , 8.91, 8.71])

# %%
prices_a[1:]/prices_a[:-1]-1
# Out:
# array([ 0.02413793, -0.02244669])

# %%
import pandas as pd 
prices = pd.DataFrame({"BLUE":[8.70,8.91,8.71,8.43,8.73]
                      ,
                     "ORANGE":[10.66,11.08,10.71,11.59,12.11]})

# %%
prices
# Out:
#    BLUE  ORANGE
# 0  8.70   10.66
# 1  8.91   11.08
# 2  8.71   10.71
# 3  8.43   11.59
# 4  8.73   12.11

# %%
prices.iloc[1:]
# Out:
#    BLUE  ORANGE
# 1  8.91   11.08
# 2  8.71   10.71
# 3  8.43   11.59
# 4  8.73   12.11

# %%
prices.iloc[:-1]
# Out:
#    BLUE  ORANGE
# 0  8.70   10.66
# 1  8.91   11.08
# 2  8.71   10.71
# 3  8.43   11.59

# %%
prices.iloc[1:].values/prices.iloc[:-1]-1
# Out:
#        BLUE    ORANGE
# 0  0.024138  0.039400
# 1 -0.022447 -0.033394
# 2 -0.032147  0.082166
# 3  0.035587  0.044866

# %%
prices/prices.shift(1)-1
# Out:
#        BLUE    ORANGE
# 0       NaN       NaN
# 1  0.024138  0.039400
# 2 -0.022447 -0.033394
# 3 -0.032147  0.082166
# 4  0.035587  0.044866

# %%
prices
# Out:
#    BLUE  ORANGE
# 0  8.70   10.66
# 1  8.91   11.08
# 2  8.71   10.71
# 3  8.43   11.59
# 4  8.73   12.11

# %%
prices.pct_change()
# Out:
#        BLUE    ORANGE
# 0       NaN       NaN
# 1  0.024138  0.039400
# 2 -0.022447 -0.033394
# 3 -0.032147  0.082166
# 4  0.035587  0.044866

# %%
prices_MSFT = pd.read_csv('data/MSFT.csv')
prices_MSFT
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2021-06-14  257.899994  259.950012  256.799988  259.890015  257.785034
# 1    2021-06-15  259.769989  259.989990  257.679993  258.359985  256.267426
# 2    2021-06-16  259.399994  260.579987  254.419998  257.380005  255.295380
# 3    2021-06-17  256.070007  261.750000  256.010010  260.899994  258.786835
# 4    2021-06-18  259.630005  262.299988  258.750000  259.429993  257.328766
# ..          ...         ...         ...         ...         ...         ...
# 247  2022-06-06  272.059998  274.179993  267.220001  268.750000  268.750000
# 248  2022-06-07  266.640015  273.130005  265.940002  272.500000  272.500000
# 249  2022-06-08  271.709991  273.000000  269.609985  270.410004  270.410004
# 250  2022-06-09  267.779999  272.709991  264.630005  264.790009  264.790009
# 251  2022-06-10  260.579987  260.579987  252.529999  252.990005  252.990005
#
#        Volume
# 0    19150500
# 1    18038900
# ...

# %%
prices_MSFT.plot()
# Out:
# <AxesSubplot:>

# %%
# %matplotlib inline

# %%
protfolio

# %%
import pandas as pd
import matplotlib.pyplot as plt

dataframe = pd.DataFrame({'Value':[100, 200, 300]})
axis = dataframe.plot.bar(rot=0)
print(axis)
plt.show()
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataframe = pd.prices_MSFT
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 dataframe = pd.prices_MSFT
#
# File ~\anaconda3\lib\site-packages\pandas\__init__.py:261, in __getattr__(name)
#     257     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     259     return _SparseArray
# --> 261 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'prices_MSFT'

# %%
import yfinance as yf 

MICROSOFT='MSFT'

data = yf.Ticker(MICROSOFT)

dataDF= data.history(period ='id', start='2021-1-1', end='2021-3-1')
                     
dataDF
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2020-12-31  218.893590  220.177137  216.899156  219.604477  20942100
# 2021-01-04  219.713101  220.177153  212.090824  214.934372  37130100
# 2021-01-05  214.509810  215.753870  212.969560  215.141708  23823000
# 2021-01-06  209.484228  213.749550  209.257144  209.563217  35930700
# 2021-01-07  211.330548  216.563460  211.004738  215.526749  27694500
# 2021-01-08  215.911832  217.787790  214.282724  216.839935  22956200
# 2021-01-11  215.704498  216.138931  213.986519  214.736908  23031300
# 2021-01-12  213.759423  214.351834  210.619684  212.209290  23249300
# 2021-01-13  211.310831  214.016137  211.221959  213.601456  20087100
# 2021-01-14  213.176903  214.707285  210.047032  210.323486  29480800
# 2021-01-15  210.817142  211.794601  209.345998  209.958145  31746500
# 2021-01-19  211.044229  214.233338  209.938412  213.700180  30480900
# ...

# %%
import yfinance as yf 

Alphabet_inc='GOOGL'

data = yf.Ticker(Alphabet_inc)

dataDF2= data.history(period ='id', start='2021-1-1', end='2021-3-1')
                     
dataDF2
# Out:
#                    Open         High          Low        Close   Volume  \
# Date
# 2020-12-31  1737.270020  1757.500000  1736.089966  1752.640015  1053500
# 2021-01-04  1760.000000  1762.489990  1707.140015  1726.130005  1866200
# 2021-01-05  1725.089966  1746.829956  1716.900024  1740.050049  1018000
# 2021-01-06  1700.260010  1743.969971  1696.099976  1722.880005  2329400
# 2021-01-07  1726.760010  1777.819946  1726.760010  1774.339966  2096800
# 2021-01-08  1777.160034  1799.359985  1761.219971  1797.829956  1774200
# 2021-01-11  1777.020020  1784.380005  1752.140015  1756.290039  1739800
# 2021-01-12  1745.359985  1767.900024  1716.380005  1737.430054  1476400
# 2021-01-13  1727.319946  1756.390015  1727.319946  1747.250000  1171600
# 2021-01-14  1748.869995  1767.550049  1726.069946  1730.920044  1460600
# 2021-01-15  1729.020020  1747.619995  1711.709961  1727.619995  1572200
# 2021-01-19  1743.000000  1803.839966  1732.829956  1784.469971  2083000
# ...

# %%
Df = yf.download(Alphabet_inc, start='2015-1-1', end='2021-3-1') 
df['returns']= df.Close.pct_change()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df = df.dropna()
plt.hist(df.returns, bins=38)
plt.xlabel('Returns')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
VaR_90 = df['returns'].quantille(0.1)
VaR_95 = df['returns'].quantille(0.05)
VaR_99 = df['returns'].quantille(0.01)

print df([['90%', var_90], ['95%', var_95],['99%', var_99]])
# Out:
#   Input In [54]
#     print df([['90%', var_90], ['95%', var_95],['99%', var_99]])
#           ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt

dataDF2['Close'].plot()

plt.show()

# %%
dataDF2['Close'].plot.bar()
plt.show()

# %%
dataDF2['Close'].mean()
# Out:
# 1924.61666791867

# %%
dataDF2['Close'].()

# %%
dataDF2['Close'].var()
# Out:
# 21270.64961149326

# %%
dataDF2['Close'].std()
# Out:
# 145.84460775597177

# %%
dataDF2['Close'].std() == (dataDF2['Close'].var())**0.5
# Out:
# True
